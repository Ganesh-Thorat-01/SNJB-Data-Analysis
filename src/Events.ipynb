# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRS0z-BpUNElIthEL3DrT5XPoNLO3kaZIHn7yj-trP1nHXPeeDCPvxvGtRl2OEvbgTmgKT5iuZ6u-LZ/pub?gid=235013835&single=true&output=csv")

# %%
df
# Out:
#   Academic Year  SPACE  SPACE/CSI & IAITE  SPACE & CSI  CSI  EDC  SNJB  Dept  \
# 0       2015-16    5.0                NaN          NaN  NaN  3.0   1.0   NaN
# 1       2016-17    2.0                NaN          NaN  4.0  2.0   NaN   NaN
# 2       2017-18    1.0                NaN          NaN  2.0  NaN   NaN  10.0
# 3       2018-19    7.0                NaN          NaN  8.0  NaN   NaN  13.0
# 4       2019-20    3.0                1.0          4.0  NaN  NaN   NaN  17.0
# 5       2020-21    NaN                3.0          2.0  NaN  NaN   NaN  26.0
# 6       2021-22    NaN                NaN          NaN  NaN  NaN   NaN   NaN
# 7       2022-23    NaN                NaN          NaN  NaN  NaN   NaN   NaN
#
#    Dept Comp  Dept Comp/IT  ...  Dept Activity(Social)  SPPU  By Zensar  \
# 0        NaN           NaN  ...                    NaN   NaN        NaN
# 1        NaN           NaN  ...                    2.0   NaN        NaN
# ...

# %%
df=df[["Academic Year","Total"]]

# %%
df
# Out:
#   Academic Year  Total
# 0       2015-16   17.0
# 1       2016-17   31.0
# 2       2017-18   27.0
# 3       2018-19   29.0
# 4       2019-20   47.0
# 5       2020-21   32.0
# 6       2021-22    NaN
# 7       2022-23    NaN

# %%
df.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df
# Out:
#   Academic Year  Total
# 0       2015-16   17.0
# 1       2016-17   31.0
# 2       2017-18   27.0
# 3       2018-19   29.0
# 4       2019-20   47.0
# 5       2020-21   32.0

# %%
df.describe()
# Out:
#            Total
# count   6.000000
# mean   30.500000
# std     9.710819
# min    17.000000
# 25%    27.500000
# 50%    30.000000
# 75%    31.750000
# max    47.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Academic Year  6 non-null      object
#  1   Total          6 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes

# %%
df.plot()
plt.show()

# %%
def dash(value):
    value = str(value)
    if '-' in value:
        value = value.split('-')[0]
        return int(value)
    else:
        return int(value)

# %%
df["Academic Year"]=df["Academic Year"].apply(dash)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#    Academic Year  Total
# 0           2015   17.0
# 1           2016   31.0
# 2           2017   27.0
# 3           2018   29.0
# 4           2019   47.0
# 5           2020   32.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Academic Year  6 non-null      int64
#  1   Total          6 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 144.0 bytes

# %%
x_train=df[["Academic Year"]]

# %%
y_train=df["Total"]

# %%
x_train
# Out:
#    Academic Year
# 0           2015
# 1           2016
# 2           2017
# 3           2018
# 4           2019
# 5           2020

# %%
y_train
# Out:
# 0    17.0
# 1    31.0
# 2    27.0
# 3    29.0
# 4    47.0
# 5    32.0
# Name: Total, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import numpy as np

# %%
#create, train and do inference of the model
model = RandomForestRegressor()
model.fit(x_train, y_train)
predictions = model.predict(x_train)

#calculate MAE
mae = np.round(mean_absolute_error(y_train, predictions), 3)

# %%
mae
# Out:
# 3.253

# %%
import pickle
import os

with open('Events.pkl', 'wb') as fileWriteStream:
    pickle.dump(model, fileWriteStream)
    fileWriteStream.close()
